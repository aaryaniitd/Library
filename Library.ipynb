# %%
from ipynb.fs.full.code import execute
# Out:
# Welcome to Aaryan's Library. Enter your choice to continue
#
# 1. Search a Book
# 2. Display All Books
# 3. Lend a Book
# 4. Return a Book
# 5. Donate a Book
#
# 2
#
#
# We have the following books in our library:
#
# The Last Mysteries of The World
# The Journey to the Centre of the Earth
# A Brief History of Time
# Theory of Everything
# The Story of My Life
# The Adventures of Tom Sawyer
# Death on the Nile
# The Theory of Relativity
# Revolution 2020
# Rich Dad Poor Dad
# Electrodynamics by David J. Griffiths
# Geetanjali
# My Experiments with Truth
# All About Dinosaurs
#
#
# Do you want to see the available options again? yes
#
#
# 1. Search a Book
# 2. Display Books
# 3. Lend a Book
# 4. Return a Book
# 5. Donate a Book
#
# 3
#
#
# Enter the name of the book you want to lend. A Brief History of Time
# Enter your name. Aaryan
# Lender-Book database has been updated. You can take your book.
#
# Do you want to see the available options again? yes
#
#
# 1. Search a Book
# ...
